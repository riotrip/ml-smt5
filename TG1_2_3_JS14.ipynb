# %% [markdown]
# <a href="https://colab.research.google.com/github/riotrip/ml-smt5/blob/main/TG1_2_3_JS14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Rio Tri Prayogo - 2341720236 - TI 3F/25**
# ---
# ## **JS14 - Convolutional Neural Network**

# %% [markdown]
# ### **Tugas Lab**
# - Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%.
# - Buatlah model CNN untuk klasifikasi dataset MNIST.
